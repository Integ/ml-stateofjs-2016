# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing

df = pd.read_excel('State Of JavaScript 2016 (clean).xlsx')

# %%
# clean Favorite Editor
df['Favorite Text Editor'].fillna(df['Other'], inplace=True)
editor = df['Favorite Text Editor'].str.lower()
editor.replace(regex='.*code.*', value='visual studio [code]', inplace=True)
editor.replace(regex='.*visual.*', value='visual studio [code]', inplace=True)
editor.replace(regex='.*vs.*', value='visual studio [code]', inplace=True)
editor.replace(regex='.*idea.*', value='intellij idea', inplace=True)
editor.replace(regex='.*intellij.*', value='intellij idea', inplace=True)

df['Favorite Text Editor'] = editor
editor.value_counts()[0:10].plot.bar()
plt.show()

# %%
df['Yearly Salary'].value_counts().plot.bar()
plt.show()

# %%
df['Years of Experience'].value_counts().plot.bar()
plt.show()

# %%
df.loc[df['Years of Experience']=='20+ years', 'Favorite Text Editor'].value_counts()[0:10].plot.bar()
plt.show()

# %%
df.loc[df['Yearly Salary']=='$200k+', 'Favorite Text Editor'].value_counts()[0:10].plot.bar()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9306 entries, 0 to 9305
# Data columns (total 91 columns):
# #                                                                                                             9306 non-null object
# Good Old Plain JavaScript                                                                                     9306 non-null object
# ES6                                                                                                           9305 non-null object
# CoffeeScript                                                                                                  9305 non-null object
# TypeScript                                                                                                    9305 non-null object
# Elm                                                                                                           9305 non-null object
# ClojureScript                                                                                                 9305 non-null object
# On a scale of one to five dogs, how happy are you with your current flavor of JavaScript?                     9264 non-null float64
# No Front-End Framework                                                                                        9305 non-null object
# React                                                                                                         9305 non-null object
# Angular                                                                                                       9305 non-null object
# Angular 2                                                                                                     9305 non-null object
# Ember                                                                                                         9305 non-null object
# Vue                                                                                                           9305 non-null object
# Backbone                                                                                                      9305 non-null object
# Other Front-End Frameworks                                                                                    1923 non-null object
# On a scale of one to five cats, how happy are you with your current solution for the front-end?               9202 non-null float64
# Redux                                                                                                         9305 non-null object
# MobX                                                                                                          9305 non-null object
# Relay                                                                                                         9305 non-null object
# Other State Management Libraries                                                                              844 non-null object
# On a scale of one to five thunderbolts, how happy are you with your current solution for state management?    8675 non-null float64
# Custom REST API                                                                                               9305 non-null object
# Firebase                                                                                                      9305 non-null object
# GraphQL                                                                                                       9305 non-null object
# Apollo                                                                                                        9305 non-null object
# Falcor                                                                                                        9305 non-null object
# Horizon                                                                                                       9305 non-null object
# Other API layer solutions                                                                                     544 non-null object
# On a scale of one to five crowns, how happy are you with your current solution for the API layer?             8910 non-null float64
# Meteor                                                                                                        9305 non-null object
# FeathersJS                                                                                                    9305 non-null object
# DoneJS                                                                                                        9305 non-null object
# MERN                                                                                                          9305 non-null object
# MEAN                                                                                                          9305 non-null object
# Other stacks                                                                                                  493 non-null object
# On a scale of one to five trophies, how happy are you with your current full-stack solution?                  8485 non-null float64
# Mocha                                                                                                         9305 non-null object
# Jasmine                                                                                                       9305 non-null object
# Enzyme                                                                                                        9305 non-null object
# Jest                                                                                                          9305 non-null object
# Cucumber                                                                                                      9305 non-null object
# Ava                                                                                                           9305 non-null object
# Other testing frameworks                                                                                      838 non-null object
# On a scale of one to five severed hands, how happy are you with the current state of JavaScript testing?      8700 non-null float64
# Plain CSS                                                                                                     9305 non-null object
# SASS/SCSS                                                                                                     9305 non-null object
# LESS                                                                                                          9305 non-null object
# CSS Modules                                                                                                   9305 non-null object
# Aphrodite                                                                                                     9305 non-null object
# Other CSS solutions                                                                                           1068 non-null object
# On a scale of one to five lightbulbs, how happy are you with the current state of CSS?                        9076 non-null float64
# Webpack                                                                                                       9305 non-null object
# Grunt                                                                                                         9305 non-null object
# Gulp                                                                                                          9305 non-null object
# Browserify                                                                                                    9305 non-null object
# Bower                                                                                                         9305 non-null object
# Other build tools                                                                                             1162 non-null object
# On a scale of one to five droplets, how happy are you with the current state of build tools?                  9057 non-null float64
# Native Apps                                                                                                   9305 non-null object
# React Native                                                                                                  9305 non-null object
# Cordova                                                                                                       9305 non-null object
# PhoneGap                                                                                                      9305 non-null object
# NativeScript                                                                                                  9305 non-null object
# Other mobile apps solutions                                                                                   691 non-null object
# On a scale of one to five pencils, how happy are you with the current state of mobile apps?                   8516 non-null float64
# Server-Side Rendering                                                                                         9156 non-null object
# Code Splitting                                                                                                9244 non-null object
# Optimistic Updates                                                                                            9228 non-null object
# Hot Module Reloading                                                                                          9236 non-null object
# Time-Travel Debugging                                                                                         9221 non-null object
# Real-Time Operations                                                                                          9214 non-null object
# Dead Code Elimination                                                                                         9218 non-null object
# Progressive Enhancement                                                                                       9219 non-null object
# Other Features                                                                                                230 non-null object
# JavaScript is moving in the right direction                                                                   9206 non-null float64
# Building JavaScript apps is overly complex right now                                                          9228 non-null float64
# JavaScript is over-used online                                                                                9240 non-null float64
# I enjoy building JavaScript apps                                                                              9240 non-null float64
# I would like JavaScript to be my main programming language                                                    9241 non-null float64
# The JavaScript ecosystem is changing too fast                                                                 9244 non-null float64
# This survey is too damn long!                                                                                 9249 non-null float64
# Years of Experience                                                                                           9256 non-null object
# Company Size                                                                                                  9214 non-null object
# Yearly Salary                                                                                                 8876 non-null object
# Favorite Text Editor                                                                                          9102 non-null object
# Other                                                                                                         1493 non-null object
# Tabs or Spaces?                                                                                               9152 non-null object
# Other Comments                                                                                                959 non-null object
# Start Date (UTC)                                                                                              9306 non-null datetime64[ns]
# Submit Date (UTC)                                                                                             9306 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(16), object(73)
# memory usage: 6.5+ MB
